# %% [markdown]
# ### Time-Series Analysis using LSTM: Dhaka Tribune
#
# ### Highlights
#
# * Dataset: Dhaka Tribune 2021 Dataset.
# * Training Period: 2016-06-26 to 2021-04-27
# * Test/Validation Period: 2021-04-28 to 2021-06-28
#
# Created on: 07/07/2021
#
# Updated on: 08/02/2021

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from datetime import datetime, timedelta
import warnings
import matplotlib.pyplot as plt
from keras import optimizers
from keras.utils import plot_model
from keras.models import Sequential, Model
from keras.layers import Dense, LSTM, RepeatVector, TimeDistributed, Flatten, Dropout
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
#import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %matplotlib inline
warnings.filterwarnings("ignore")
init_notebook_mode(connected=True)

# Set seeds to make the experiment more reproducible.
from numpy.random import seed
seed(1)
from tensorflow import random
random.set_seed(1)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Load & Preprocess Dataset

# %%
df = pd.read_csv('../input/dhakatribunecomplete/Dhaka Tribune Complete Data.csv')
df['Accident date'] = pd.to_datetime(df['Accident date'])
df = df[['Accident date', 'Deaths']]
df = df.dropna()
df.columns = ['Period', 'Deaths']
df = df.sort_values(by = 'Period')
df = df.reset_index(drop = True).set_index('Period').resample('1W').sum()
df = df.reset_index()
df['Period'] = df['Period'].dt.date
#df['Deaths'] = df['Deaths'].fillna(0)
df
# Out:
#          Period  Deaths
# 0    2016-06-26     3.0
# 1    2016-07-03     0.0
# 2    2016-07-10     0.0
# 3    2016-07-17     4.0
# 4    2016-07-24     0.0
# ..          ...     ...
# 257  2021-05-30     3.0
# 258  2021-06-06    11.0
# 259  2021-06-13     8.0
# 260  2021-06-20    16.0
# 261  2021-06-27     5.0
#
# [262 rows x 2 columns]

# %%
df.dtypes
# Out:
# Period     object
# Deaths    float64
# dtype: object

# %% [markdown]
# ### Splitting into Train & Test Sets

# %%
start_ = df.Period.max()
end_ = df.Period.min()

test_end = df.Period.max()
test_start = df.Period.max() - timedelta(days = 60)

train_end = test_start - timedelta(days = 1)
train_start = train_end - timedelta(days = 365*5)

print('Dataset Start Date: {}'.format(start_))
print('Dataset End Date: {}'.format(end_))
print (' ')
print('Train Set Start Date: {}'.format(train_start))
print('Train Set End Date: {}'.format(train_end))
print (' ')
print('Test Set Start Date: {}'.format(test_start))
print('Test Set End Date: {}'.format(test_end))
print (' ')
# Out:
# Dataset Start Date: 2021-06-27
# Dataset End Date: 2016-06-26
#
# Train Set Start Date: 2016-04-28
# Train Set End Date: 2021-04-27
#
# Test Set Start Date: 2021-04-28
# Test Set End Date: 2021-06-27

# %%
mask = (df.Period > train_start) & (df.Period <= train_end)
train = df.loc[mask]

mask = (df.Period >= test_start) & (df.Period <= test_end)
test = df.loc[mask]

# %%
train.tail()
# Out:
#          Period  Deaths
# 248  2021-03-28    26.0
# 249  2021-04-04     7.0
# 250  2021-04-11     4.0
# 251  2021-04-18    25.0
# 252  2021-04-25     6.0

# %%
test.head()
# Out:
#          Period  Deaths
# 253  2021-05-02    12.0
# 254  2021-05-09    11.0
# 255  2021-05-16    20.0
# 256  2021-05-23    28.0
# 257  2021-05-30     3.0

# %%
d = pd.concat([train, test])
d = d.reset_index(drop = True)
d
# Out:
#          Period  Deaths
# 0    2016-06-26     3.0
# 1    2016-07-03     0.0
# 2    2016-07-10     0.0
# 3    2016-07-17     4.0
# 4    2016-07-24     0.0
# ..          ...     ...
# 257  2021-05-30     3.0
# 258  2021-06-06    11.0
# 259  2021-06-13     8.0
# 260  2021-06-20    16.0
# 261  2021-06-27     5.0
#
# [262 rows x 2 columns]

# %% [markdown]
# ### Transform the data into a time series problem

# %%
def series_to_supervised(data, window=1, lag=1, dropnan=True):
    cols, names = list(), list()
    # Input sequence (t-n, ... t-1)
    for i in range(window, 0, -1):
        cols.append(data.shift(i))
        names += [('%s(t-%d)' % (col, i)) for col in data.columns]
    # Current timestep (t=0)
    cols.append(data)
    names += [('%s(t)' % (col)) for col in data.columns]
    # Target timestep (t=lag)
    cols.append(data.shift(-lag))
    names += [('%s(t+%d)' % (col, lag)) for col in data.columns]
    # Put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # Drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %% [markdown]
# ### We will use the present day and the last 3 days data to forecast 1 day's results ahead

# %%
window = 2
lag = 1
series = series_to_supervised(d.drop('Period', axis=1), window=window, lag=lag)
series
# Out:
#      Deaths(t-2)  Deaths(t-1)  Deaths(t)  Deaths(t+1)
# 2            3.0          0.0        0.0          4.0
# 3            0.0          0.0        4.0          0.0
# 4            0.0          4.0        0.0          0.0
# 5            4.0          0.0        0.0          3.0
# 6            0.0          0.0        3.0          1.0
# ..           ...          ...        ...          ...
# 256         11.0         20.0       28.0          3.0
# 257         20.0         28.0        3.0         11.0
# 258         28.0          3.0       11.0          8.0
# 259          3.0         11.0        8.0         16.0
# 260         11.0          8.0       16.0          5.0
#
# [259 rows x 4 columns]

# %%
lag_size = 1 

# Label
labels_col = 'Deaths(t+%d)' % lag_size
labels = series[[labels_col]]
series = series.drop(labels_col, axis=1)
series
# Out:
#      Deaths(t-2)  Deaths(t-1)  Deaths(t)
# 2            3.0          0.0        0.0
# 3            0.0          0.0        4.0
# 4            0.0          4.0        0.0
# 5            4.0          0.0        0.0
# 6            0.0          0.0        3.0
# ..           ...          ...        ...
# 256         11.0         20.0       28.0
# 257         20.0         28.0        3.0
# 258         28.0          3.0       11.0
# 259          3.0         11.0        8.0
# 260         11.0          8.0       16.0
#
# [259 rows x 3 columns]

# %%
labels
# Out:
#      Deaths(t+1)
# 2            4.0
# 3            0.0
# 4            0.0
# 5            3.0
# 6            1.0
# ..           ...
# 256          3.0
# 257         11.0
# 258          8.0
# 259         16.0
# 260          5.0
#
# [259 rows x 1 columns]

# %%
X_train = series[:len(train)- window]
X_train
# Out:
#      Deaths(t-2)  Deaths(t-1)  Deaths(t)
# 2            3.0          0.0        0.0
# 3            0.0          0.0        4.0
# 4            0.0          4.0        0.0
# 5            4.0          0.0        0.0
# 6            0.0          0.0        3.0
# ..           ...          ...        ...
# 248          5.0         14.0       26.0
# 249         14.0         26.0        7.0
# 250         26.0          7.0        4.0
# 251          7.0          4.0       25.0
# 252          4.0         25.0        6.0
#
# [251 rows x 3 columns]

# %%
Y_train = labels[:len(train)- window]
Y_train
# Out:
#      Deaths(t+1)
# 2            4.0
# 3            0.0
# 4            0.0
# 5            3.0
# 6            1.0
# ..           ...
# 248          7.0
# 249          4.0
# 250         25.0
# 251          6.0
# 252         12.0
#
# [251 rows x 1 columns]

# %%
X_valid = series[len(train)- window:]
X_valid
# Out:
#      Deaths(t-2)  Deaths(t-1)  Deaths(t)
# 253         25.0          6.0       12.0
# 254          6.0         12.0       11.0
# 255         12.0         11.0       20.0
# 256         11.0         20.0       28.0
# 257         20.0         28.0        3.0
# 258         28.0          3.0       11.0
# 259          3.0         11.0        8.0
# 260         11.0          8.0       16.0

# %%
Y_valid = labels[len(train)- window:]
Y_valid
# Out:
#      Deaths(t+1)
# 253         11.0
# 254         20.0
# 255         28.0
# 256          3.0
# 257         11.0
# 258          8.0
# 259         16.0
# 260          5.0

# %%
print('Train set shape', X_train.shape)
print('Validation set shape', X_valid.shape)

print('Train labels shape', Y_train.shape)
print('Validation labels shape', Y_valid.shape)
# Out:
# Train set shape (251, 3)
# Validation set shape (8, 3)
# Train labels shape (251, 1)
# Validation labels shape (8, 1)

# %% [markdown]
# ### Data Preprocess
#
# * Reshape from [samples, timesteps] into [samples, timesteps, 1].
#
# **Note: timestep = window + lag**
#
# * In our case, window = 3, lag = 1.

# %%
X_train_series = X_train.values.reshape((X_train.shape[0], X_train.shape[1], 1))
X_valid_series = X_valid.values.reshape((X_valid.shape[0], X_valid.shape[1], 1))
print('Train set shape', X_train_series.shape)
print('Validation set shape', X_valid_series.shape)
# Out:
# Train set shape (251, 3, 1)
# Validation set shape (8, 3, 1)

# %% [markdown]
# ### Model Development: LSTM

# %%
epochs = 500
batch = 32
lr = 0.0008
adam = optimizers.Adam(lr)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=70)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=70, verbose=1)

# %%
model_lstm = Sequential()
model_lstm.add(LSTM(50, activation='relu', input_shape=(X_train_series.shape[1], X_train_series.shape[2])))
#model_lstm.add(LSTM(50,activation="relu",return_sequences=True))
#model_lstm.add(LSTM(50,activation="relu"))
#model_lstm.add(Dropout(0.1))
model_lstm.add(Dense(1))
model_lstm.compile(loss='mae', optimizer=adam)
model_lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 50)                10400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 10,451
# Trainable params: 10,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
lstm_history = model_lstm.fit(X_train_series, Y_train, validation_data=(X_valid_series, Y_valid), epochs=epochs, verbose=1, callbacks=[es, mcp, rlr])
# Out:
# Epoch 1/500
# 8/8 [==============================] - 2s 117ms/step - loss: 12.3846 - val_loss: 12.3708
#
# Epoch 00001: val_loss improved from inf to 12.37079, saving model to weights.h5
# Epoch 2/500
# 8/8 [==============================] - 0s 18ms/step - loss: 13.2128 - val_loss: 11.9853
#
# Epoch 00002: val_loss improved from 12.37079 to 11.98532, saving model to weights.h5
# Epoch 3/500
# 8/8 [==============================] - 0s 19ms/step - loss: 12.5828 - val_loss: 11.5584
#
# Epoch 00003: val_loss improved from 11.98532 to 11.55838, saving model to weights.h5
# Epoch 4/500
# 8/8 [==============================] - 0s 19ms/step - loss: 13.5412 - val_loss: 11.0202
#
# Epoch 00004: val_loss improved from 11.55838 to 11.02018, saving model to weights.h5
# Epoch 5/500
# 8/8 [==============================] - 0s 19ms/step - loss: 11.8615 - val_loss: 10.4825
#
# Epoch 00005: val_loss improved from 11.02018 to 10.48250, saving model to weights.h5
# Epoch 6/500
# 8/8 [==============================] - 0s 19ms/step - loss: 10.7229 - val_loss: 9.8442
#
# Epoch 00006: val_loss improved from 10.48250 to 9.84423, saving model to weights.h5
# Epoch 7/500
# 8/8 [==============================] - 0s 19ms/step - loss: 11.3191 - val_loss: 9.0330
#
# Epoch 00007: val_loss improved from 9.84423 to 9.03301, saving model to weights.h5
# Epoch 8/500
# 8/8 [==============================] - 0s 19ms/step - loss: 10.9040 - val_loss: 8.0221
#
# Epoch 00008: val_loss improved from 9.03301 to 8.02214, saving model to weights.h5
# Epoch 9/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.2343 - val_loss: 7.5112
#
# Epoch 00009: val_loss improved from 8.02214 to 7.51119, saving model to weights.h5
# Epoch 10/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.5216 - val_loss: 7.4923
#
# Epoch 00010: val_loss improved from 7.51119 to 7.49232, saving model to weights.h5
# Epoch 11/500
# 8/8 [==============================] - 0s 19ms/step - loss: 10.6860 - val_loss: 7.3901
#
# Epoch 00011: val_loss improved from 7.49232 to 7.39009, saving model to weights.h5
# Epoch 12/500
# 8/8 [==============================] - 0s 19ms/step - loss: 7.8527 - val_loss: 7.5347
#
# Epoch 00012: val_loss did not improve from 7.39009
# Epoch 13/500
# 8/8 [==============================] - 0s 18ms/step - loss: 8.7551 - val_loss: 7.7492
#
# Epoch 00013: val_loss did not improve from 7.39009
# Epoch 14/500
# 8/8 [==============================] - 0s 18ms/step - loss: 10.9753 - val_loss: 8.1131
#
# Epoch 00014: val_loss did not improve from 7.39009
# Epoch 15/500
# 8/8 [==============================] - 0s 18ms/step - loss: 9.3424 - val_loss: 7.8301
#
# Epoch 00015: val_loss did not improve from 7.39009
# Epoch 16/500
# 8/8 [==============================] - 0s 19ms/step - loss: 10.4039 - val_loss: 7.6644
#
# Epoch 00016: val_loss did not improve from 7.39009
# Epoch 17/500
# 8/8 [==============================] - 0s 18ms/step - loss: 8.8650 - val_loss: 7.9852
#
# Epoch 00017: val_loss did not improve from 7.39009
# Epoch 18/500
# 8/8 [==============================] - 0s 18ms/step - loss: 11.2537 - val_loss: 8.2355
#
# Epoch 00018: val_loss did not improve from 7.39009
# Epoch 19/500
# 8/8 [==============================] - 0s 18ms/step - loss: 10.7125 - val_loss: 8.2400
#
# Epoch 00019: val_loss did not improve from 7.39009
# Epoch 20/500
# 8/8 [==============================] - 0s 19ms/step - loss: 10.8564 - val_loss: 7.7968
#
# Epoch 00020: val_loss did not improve from 7.39009
# Epoch 21/500
# 8/8 [==============================] - 0s 19ms/step - loss: 10.5327 - val_loss: 7.6777
#
# Epoch 00021: val_loss did not improve from 7.39009
# Epoch 22/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.1124 - val_loss: 7.6949
#
# Epoch 00022: val_loss did not improve from 7.39009
# Epoch 23/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.7346 - val_loss: 7.9298
#
# Epoch 00023: val_loss did not improve from 7.39009
# Epoch 24/500
# 8/8 [==============================] - 0s 19ms/step - loss: 10.3240 - val_loss: 7.8879
#
# Epoch 00024: val_loss did not improve from 7.39009
# Epoch 25/500
# 8/8 [==============================] - 0s 18ms/step - loss: 9.5660 - val_loss: 7.6363
#
# Epoch 00025: val_loss did not improve from 7.39009
# Epoch 26/500
# 8/8 [==============================] - 0s 18ms/step - loss: 9.0752 - val_loss: 7.7269
#
# Epoch 00026: val_loss did not improve from 7.39009
# Epoch 27/500
# 8/8 [==============================] - 0s 19ms/step - loss: 10.5112 - val_loss: 7.7651
#
# Epoch 00027: val_loss did not improve from 7.39009
# Epoch 28/500
# 8/8 [==============================] - 0s 19ms/step - loss: 10.1686 - val_loss: 7.5250
#
# Epoch 00028: val_loss did not improve from 7.39009
# Epoch 29/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.3439 - val_loss: 7.5927
#
# Epoch 00029: val_loss did not improve from 7.39009
# Epoch 30/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.1826 - val_loss: 7.5636
#
# Epoch 00030: val_loss did not improve from 7.39009
# Epoch 31/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.0795 - val_loss: 7.5571
#
# Epoch 00031: val_loss did not improve from 7.39009
# Epoch 32/500
# 8/8 [==============================] - 0s 20ms/step - loss: 9.1233 - val_loss: 7.5310
#
# Epoch 00032: val_loss did not improve from 7.39009
# Epoch 33/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.7209 - val_loss: 7.5685
#
# Epoch 00033: val_loss did not improve from 7.39009
# Epoch 34/500
# 8/8 [==============================] - 0s 20ms/step - loss: 8.6856 - val_loss: 7.5353
#
# Epoch 00034: val_loss did not improve from 7.39009
# Epoch 35/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.5796 - val_loss: 7.5499
#
# Epoch 00035: val_loss did not improve from 7.39009
# Epoch 36/500
# 8/8 [==============================] - 0s 18ms/step - loss: 7.7077 - val_loss: 7.4820
#
# Epoch 00036: val_loss did not improve from 7.39009
# Epoch 37/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.3676 - val_loss: 7.5419
#
# Epoch 00037: val_loss did not improve from 7.39009
# Epoch 38/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.6213 - val_loss: 7.4813
#
# Epoch 00038: val_loss did not improve from 7.39009
# Epoch 39/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.5471 - val_loss: 7.5292
#
# Epoch 00039: val_loss did not improve from 7.39009
# Epoch 40/500
# 8/8 [==============================] - 0s 20ms/step - loss: 9.1520 - val_loss: 7.4956
#
# Epoch 00040: val_loss did not improve from 7.39009
# Epoch 41/500
# 8/8 [==============================] - 0s 20ms/step - loss: 8.3011 - val_loss: 7.4067
#
# Epoch 00041: val_loss did not improve from 7.39009
# Epoch 42/500
# 8/8 [==============================] - 0s 19ms/step - loss: 10.6650 - val_loss: 7.4814
#
# Epoch 00042: val_loss did not improve from 7.39009
# Epoch 43/500
# 8/8 [==============================] - 0s 20ms/step - loss: 9.2088 - val_loss: 7.4575
#
# Epoch 00043: val_loss did not improve from 7.39009
# Epoch 44/500
# 8/8 [==============================] - 0s 23ms/step - loss: 10.5694 - val_loss: 7.4277
#
# Epoch 00044: val_loss did not improve from 7.39009
# Epoch 45/500
# 8/8 [==============================] - 0s 22ms/step - loss: 8.8133 - val_loss: 7.4103
#
# Epoch 00045: val_loss did not improve from 7.39009
# Epoch 46/500
# 8/8 [==============================] - 0s 20ms/step - loss: 9.6005 - val_loss: 7.4262
#
# Epoch 00046: val_loss did not improve from 7.39009
# Epoch 47/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.1099 - val_loss: 7.4432
#
# Epoch 00047: val_loss did not improve from 7.39009
# Epoch 48/500
# 8/8 [==============================] - 0s 20ms/step - loss: 10.1611 - val_loss: 7.3789
#
# Epoch 00048: val_loss improved from 7.39009 to 7.37893, saving model to weights.h5
# Epoch 49/500
# 8/8 [==============================] - 0s 20ms/step - loss: 8.8704 - val_loss: 7.3557
#
# Epoch 00049: val_loss improved from 7.37893 to 7.35572, saving model to weights.h5
# Epoch 50/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.7608 - val_loss: 7.4374
#
# Epoch 00050: val_loss did not improve from 7.35572
# Epoch 51/500
# 8/8 [==============================] - 0s 20ms/step - loss: 8.4981 - val_loss: 7.3681
#
# Epoch 00051: val_loss did not improve from 7.35572
# Epoch 52/500
# 8/8 [==============================] - 0s 18ms/step - loss: 9.2304 - val_loss: 7.3474
#
# Epoch 00052: val_loss improved from 7.35572 to 7.34739, saving model to weights.h5
# Epoch 53/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.4658 - val_loss: 7.4400
#
# Epoch 00053: val_loss did not improve from 7.34739
# Epoch 54/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.8699 - val_loss: 7.4778
#
# Epoch 00054: val_loss did not improve from 7.34739
# Epoch 55/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.9147 - val_loss: 7.2674
#
# Epoch 00055: val_loss improved from 7.34739 to 7.26741, saving model to weights.h5
# Epoch 56/500
# 8/8 [==============================] - 0s 22ms/step - loss: 8.7196 - val_loss: 7.3184
#
# Epoch 00056: val_loss did not improve from 7.26741
# Epoch 57/500
# 8/8 [==============================] - 0s 21ms/step - loss: 10.5833 - val_loss: 7.4351
#
# Epoch 00057: val_loss did not improve from 7.26741
# Epoch 58/500
# 8/8 [==============================] - 0s 19ms/step - loss: 10.7031 - val_loss: 7.3148
#
# Epoch 00058: val_loss did not improve from 7.26741
# Epoch 59/500
# 8/8 [==============================] - 0s 20ms/step - loss: 8.9032 - val_loss: 7.3330
#
# Epoch 00059: val_loss did not improve from 7.26741
# Epoch 60/500
# 8/8 [==============================] - 0s 19ms/step - loss: 10.2631 - val_loss: 7.3674
#
# Epoch 00060: val_loss did not improve from 7.26741
# Epoch 61/500
# 8/8 [==============================] - 0s 19ms/step - loss: 7.4662 - val_loss: 7.3690
#
# Epoch 00061: val_loss did not improve from 7.26741
# Epoch 62/500
# 8/8 [==============================] - 0s 20ms/step - loss: 8.3435 - val_loss: 7.3602
#
# Epoch 00062: val_loss did not improve from 7.26741
# Epoch 63/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.7120 - val_loss: 7.3316
#
# Epoch 00063: val_loss did not improve from 7.26741
# Epoch 64/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.0242 - val_loss: 7.3045
#
# Epoch 00064: val_loss did not improve from 7.26741
# Epoch 65/500
# 8/8 [==============================] - 0s 20ms/step - loss: 8.2604 - val_loss: 7.2302
#
# Epoch 00065: val_loss improved from 7.26741 to 7.23018, saving model to weights.h5
# Epoch 66/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.0284 - val_loss: 7.3218
#
# Epoch 00066: val_loss did not improve from 7.23018
# Epoch 67/500
# 8/8 [==============================] - 0s 20ms/step - loss: 8.8667 - val_loss: 7.2759
#
# Epoch 00067: val_loss did not improve from 7.23018
# Epoch 68/500
# 8/8 [==============================] - 0s 20ms/step - loss: 9.7911 - val_loss: 7.3077
#
# Epoch 00068: val_loss did not improve from 7.23018
# Epoch 69/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.4225 - val_loss: 7.2586
#
# Epoch 00069: val_loss did not improve from 7.23018
# Epoch 70/500
# 8/8 [==============================] - 0s 20ms/step - loss: 8.1494 - val_loss: 7.3052
#
# Epoch 00070: val_loss did not improve from 7.23018
# Epoch 71/500
# 8/8 [==============================] - 0s 20ms/step - loss: 8.4584 - val_loss: 7.2770
#
# Epoch 00071: val_loss did not improve from 7.23018
# Epoch 72/500
# 8/8 [==============================] - 0s 19ms/step - loss: 10.4360 - val_loss: 7.2220
#
# Epoch 00072: val_loss improved from 7.23018 to 7.22203, saving model to weights.h5
# Epoch 73/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.1345 - val_loss: 7.3133
#
# Epoch 00073: val_loss did not improve from 7.22203
# Epoch 74/500
# 8/8 [==============================] - 0s 20ms/step - loss: 8.9468 - val_loss: 7.2608
#
# Epoch 00074: val_loss did not improve from 7.22203
# Epoch 75/500
# 8/8 [==============================] - 0s 20ms/step - loss: 8.4863 - val_loss: 7.2284
#
# Epoch 00075: val_loss did not improve from 7.22203
# Epoch 76/500
# 8/8 [==============================] - 0s 21ms/step - loss: 8.6535 - val_loss: 7.2668
#
# Epoch 00076: val_loss did not improve from 7.22203
# Epoch 77/500
# 8/8 [==============================] - 0s 20ms/step - loss: 8.4117 - val_loss: 7.2515
#
# Epoch 00077: val_loss did not improve from 7.22203
# Epoch 78/500
# 8/8 [==============================] - 0s 20ms/step - loss: 9.0943 - val_loss: 7.3485
#
# Epoch 00078: val_loss did not improve from 7.22203
# Epoch 79/500
# 8/8 [==============================] - 0s 20ms/step - loss: 9.2236 - val_loss: 7.2890
#
# Epoch 00079: val_loss did not improve from 7.22203
# Epoch 80/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.6460 - val_loss: 7.2127
#
# Epoch 00080: val_loss improved from 7.22203 to 7.21273, saving model to weights.h5
# Epoch 81/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.7485 - val_loss: 7.2438
#
# Epoch 00081: val_loss did not improve from 7.21273
# Epoch 82/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.3889 - val_loss: 7.2502
#
# Epoch 00082: val_loss did not improve from 7.21273
# Epoch 83/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.6236 - val_loss: 7.2417
#
# Epoch 00083: val_loss did not improve from 7.21273
# Epoch 84/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.0295 - val_loss: 7.2456
#
# Epoch 00084: val_loss did not improve from 7.21273
# Epoch 85/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.3685 - val_loss: 7.2426
#
# Epoch 00085: val_loss did not improve from 7.21273
# Epoch 86/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.4382 - val_loss: 7.2158
#
# Epoch 00086: val_loss did not improve from 7.21273
# Epoch 87/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.5751 - val_loss: 7.1476
#
# Epoch 00087: val_loss improved from 7.21273 to 7.14758, saving model to weights.h5
# Epoch 88/500
# 8/8 [==============================] - 0s 18ms/step - loss: 10.0082 - val_loss: 7.2908
#
# Epoch 00088: val_loss did not improve from 7.14758
# Epoch 89/500
# 8/8 [==============================] - 0s 20ms/step - loss: 10.1447 - val_loss: 7.2954
#
# Epoch 00089: val_loss did not improve from 7.14758
# Epoch 90/500
# 8/8 [==============================] - 0s 19ms/step - loss: 7.4875 - val_loss: 7.1951
#
# Epoch 00090: val_loss did not improve from 7.14758
# Epoch 91/500
# 8/8 [==============================] - 0s 20ms/step - loss: 8.8196 - val_loss: 7.2763
#
# Epoch 00091: val_loss did not improve from 7.14758
# Epoch 92/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.8451 - val_loss: 7.3159
#
# Epoch 00092: val_loss did not improve from 7.14758
# Epoch 93/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.2753 - val_loss: 7.2737
#
# Epoch 00093: val_loss did not improve from 7.14758
# Epoch 94/500
# 8/8 [==============================] - 0s 18ms/step - loss: 9.8994 - val_loss: 7.2432
#
# Epoch 00094: val_loss did not improve from 7.14758
# Epoch 95/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.3797 - val_loss: 7.2038
#
# Epoch 00095: val_loss did not improve from 7.14758
# Epoch 96/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.1372 - val_loss: 7.2273
#
# Epoch 00096: val_loss did not improve from 7.14758
# Epoch 97/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.2000 - val_loss: 7.2496
#
# Epoch 00097: val_loss did not improve from 7.14758
# Epoch 98/500
# 8/8 [==============================] - 0s 18ms/step - loss: 10.0472 - val_loss: 7.3834
#
# Epoch 00098: val_loss did not improve from 7.14758
# Epoch 99/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.2903 - val_loss: 7.2230
#
# Epoch 00099: val_loss did not improve from 7.14758
# Epoch 100/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.8655 - val_loss: 7.2778
#
# Epoch 00100: val_loss did not improve from 7.14758
# Epoch 101/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.3948 - val_loss: 7.2747
#
# Epoch 00101: val_loss did not improve from 7.14758
# Epoch 102/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.0346 - val_loss: 7.2378
#
# Epoch 00102: val_loss did not improve from 7.14758
# Epoch 103/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.7822 - val_loss: 7.2679
#
# Epoch 00103: val_loss did not improve from 7.14758
# Epoch 104/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.0260 - val_loss: 7.2693
#
# Epoch 00104: val_loss did not improve from 7.14758
# Epoch 105/500
# 8/8 [==============================] - 0s 18ms/step - loss: 8.1713 - val_loss: 7.3394
#
# Epoch 00105: val_loss did not improve from 7.14758
# Epoch 106/500
# 8/8 [==============================] - 0s 18ms/step - loss: 8.1344 - val_loss: 7.2853
#
# Epoch 00106: val_loss did not improve from 7.14758
# Epoch 107/500
# 8/8 [==============================] - 0s 18ms/step - loss: 8.0270 - val_loss: 7.4293
#
# Epoch 00107: val_loss did not improve from 7.14758
# Epoch 108/500
# 8/8 [==============================] - 0s 18ms/step - loss: 9.8611 - val_loss: 7.3225
#
# Epoch 00108: val_loss did not improve from 7.14758
# Epoch 109/500
# 8/8 [==============================] - 0s 18ms/step - loss: 8.6063 - val_loss: 7.3181
#
# Epoch 00109: val_loss did not improve from 7.14758
# Epoch 110/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.2943 - val_loss: 7.3000
#
# Epoch 00110: val_loss did not improve from 7.14758
# Epoch 111/500
# 8/8 [==============================] - 0s 19ms/step - loss: 7.9290 - val_loss: 7.3356
#
# Epoch 00111: val_loss did not improve from 7.14758
# Epoch 112/500
# 8/8 [==============================] - 0s 19ms/step - loss: 10.2013 - val_loss: 7.3432
#
# Epoch 00112: val_loss did not improve from 7.14758
# Epoch 113/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.7950 - val_loss: 7.3463
#
# Epoch 00113: val_loss did not improve from 7.14758
# Epoch 114/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.8083 - val_loss: 7.3332
#
# Epoch 00114: val_loss did not improve from 7.14758
# Epoch 115/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.0890 - val_loss: 7.2954
#
# Epoch 00115: val_loss did not improve from 7.14758
# Epoch 116/500
# 8/8 [==============================] - 0s 19ms/step - loss: 7.6625 - val_loss: 7.3640
#
# Epoch 00116: val_loss did not improve from 7.14758
# Epoch 117/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.2386 - val_loss: 7.3435
#
# Epoch 00117: val_loss did not improve from 7.14758
# Epoch 118/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.6207 - val_loss: 7.4423
#
# Epoch 00118: val_loss did not improve from 7.14758
# Epoch 119/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.8409 - val_loss: 7.4661
#
# Epoch 00119: val_loss did not improve from 7.14758
# Epoch 120/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.4544 - val_loss: 7.3960
#
# Epoch 00120: val_loss did not improve from 7.14758
# Epoch 121/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.8133 - val_loss: 7.4385
#
# Epoch 00121: val_loss did not improve from 7.14758
# Epoch 122/500
# 8/8 [==============================] - 0s 19ms/step - loss: 7.7793 - val_loss: 7.3601
#
# Epoch 00122: val_loss did not improve from 7.14758
# Epoch 123/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.0977 - val_loss: 7.4177
#
# Epoch 00123: val_loss did not improve from 7.14758
# Epoch 124/500
# 8/8 [==============================] - 0s 18ms/step - loss: 8.4472 - val_loss: 7.3558
#
# Epoch 00124: val_loss did not improve from 7.14758
# Epoch 125/500
# 8/8 [==============================] - 0s 19ms/step - loss: 7.9971 - val_loss: 7.3642
#
# Epoch 00125: val_loss did not improve from 7.14758
# Epoch 126/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.9016 - val_loss: 7.3768
#
# Epoch 00126: val_loss did not improve from 7.14758
# Epoch 127/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.8348 - val_loss: 7.4318
#
# Epoch 00127: val_loss did not improve from 7.14758
# Epoch 128/500
# 8/8 [==============================] - 0s 18ms/step - loss: 10.1638 - val_loss: 7.4366
#
# Epoch 00128: val_loss did not improve from 7.14758
# Epoch 129/500
# 8/8 [==============================] - 0s 18ms/step - loss: 10.2849 - val_loss: 7.4398
#
# Epoch 00129: val_loss did not improve from 7.14758
# Epoch 130/500
# 8/8 [==============================] - 0s 18ms/step - loss: 8.9455 - val_loss: 7.5010
#
# Epoch 00130: val_loss did not improve from 7.14758
# Epoch 131/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.4785 - val_loss: 7.4464
#
# Epoch 00131: val_loss did not improve from 7.14758
# Epoch 132/500
# 8/8 [==============================] - 0s 18ms/step - loss: 8.1255 - val_loss: 7.4516
#
# Epoch 00132: val_loss did not improve from 7.14758
# Epoch 133/500
# 8/8 [==============================] - 0s 19ms/step - loss: 10.3285 - val_loss: 7.5340
#
# Epoch 00133: val_loss did not improve from 7.14758
# Epoch 134/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.7256 - val_loss: 7.4178
#
# Epoch 00134: val_loss did not improve from 7.14758
# Epoch 135/500
# 8/8 [==============================] - 0s 22ms/step - loss: 9.7207 - val_loss: 7.3661
#
# Epoch 00135: val_loss did not improve from 7.14758
# Epoch 136/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.1181 - val_loss: 7.6374
#
# Epoch 00136: val_loss did not improve from 7.14758
# Epoch 137/500
# 8/8 [==============================] - 0s 18ms/step - loss: 8.4616 - val_loss: 7.6740
#
# Epoch 00137: val_loss did not improve from 7.14758
# Epoch 138/500
# 8/8 [==============================] - 0s 18ms/step - loss: 9.1882 - val_loss: 7.5771
#
# Epoch 00138: val_loss did not improve from 7.14758
# Epoch 139/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.1247 - val_loss: 7.5080
#
# Epoch 00139: val_loss did not improve from 7.14758
# Epoch 140/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.3346 - val_loss: 7.6134
#
# Epoch 00140: val_loss did not improve from 7.14758
# Epoch 141/500
# 8/8 [==============================] - 0s 18ms/step - loss: 10.5201 - val_loss: 7.5301
#
# Epoch 00141: val_loss did not improve from 7.14758
# Epoch 142/500
# 8/8 [==============================] - 0s 18ms/step - loss: 9.0445 - val_loss: 7.4600
#
# Epoch 00142: val_loss did not improve from 7.14758
# Epoch 143/500
# 8/8 [==============================] - 0s 19ms/step - loss: 9.0640 - val_loss: 7.6450
#
# Epoch 00143: val_loss did not improve from 7.14758
# Epoch 144/500
# 8/8 [==============================] - 0s 18ms/step - loss: 8.9315 - val_loss: 7.6175
#
# Epoch 00144: val_loss did not improve from 7.14758
# Epoch 145/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.4550 - val_loss: 7.7074
#
# Epoch 00145: val_loss did not improve from 7.14758
# Epoch 146/500
# 8/8 [==============================] - 0s 18ms/step - loss: 8.4687 - val_loss: 7.5882
#
# Epoch 00146: val_loss did not improve from 7.14758
# Epoch 147/500
# 8/8 [==============================] - 0s 18ms/step - loss: 9.1607 - val_loss: 7.6229
#
# Epoch 00147: val_loss did not improve from 7.14758
# Epoch 148/500
# 8/8 [==============================] - 0s 19ms/step - loss: 8.5370 - val_loss: 7.6589
#
# Epoch 00148: val_loss did not improve from 7.14758
# Epoch 149/500
# 8/8 [==============================] - 0s 18ms/step - loss: 8.5599 - val_loss: 7.4925
#
# Epoch 00149: val_loss did not improve from 7.14758
# Epoch 150/500
# 8/8 [==============================] - 0s 18ms/step - loss: 8.6650 - val_loss: 7.6728
#
# Epoch 00150: val_loss did not improve from 7.14758
# Epoch 151/500
# 8/8 [==============================] - 0s 18ms/step - loss: 8.3871 - val_loss: 7.7706
#
# Epoch 00151: val_loss did not improve from 7.14758
# Epoch 152/500
# 8/8 [==============================] - 0s 18ms/step - loss: 9.7468 - val_loss: 7.4841
#
# Epoch 00152: val_loss did not improve from 7.14758
# Epoch 153/500
# 8/8 [==============================] - 0s 18ms/step - loss: 8.4013 - val_loss: 7.6992
#
# Epoch 00153: val_loss did not improve from 7.14758
# Epoch 154/500
# 8/8 [==============================] - 0s 18ms/step - loss: 7.7331 - val_loss: 7.6101
#
# Epoch 00154: val_loss did not improve from 7.14758
# Epoch 155/500
# 8/8 [==============================] - 0s 18ms/step - loss: 8.0370 - val_loss: 7.6319
#
# Epoch 00155: val_loss did not improve from 7.14758
# Epoch 156/500
# 8/8 [==============================] - 0s 18ms/step - loss: 9.3900 - val_loss: 7.6194
#
# Epoch 00156: val_loss did not improve from 7.14758
# Epoch 157/500
# 8/8 [==============================] - 0s 18ms/step - loss: 8.9023 - val_loss: 7.6043
#
# Epoch 00157: val_loss did not improve from 7.14758
#
# Epoch 00157: ReduceLROnPlateau reducing learning rate to 7.999999797903001e-05.
# Epoch 00157: early stopping
# CPU times: user 26.1 s, sys: 1.19 s, total: 27.3 s
# Wall time: 23.9 s

# %%
# %%time
lstm_valid_pred = model_lstm.predict(X_valid_series)
# Out:
# CPU times: user 209 ms, sys: 1.86 ms, total: 211 ms
# Wall time: 208 ms

# %%
comparison = test.copy()
comparison = comparison[:len(test)-lag]
comparison['Prediction'] = lstm_valid_pred
comparison['Prediction'] = round(comparison['Prediction'])
comparison.columns = ['Date', 'Actual Death Count', 'Prediction']
comparison = comparison.set_index('Date')
comparison.to_csv('forecast.csv')
comparison
# Out:
#             Actual Death Count  Prediction
# Date
# 2021-05-02                12.0        14.0
# 2021-05-09                11.0        12.0
# 2021-05-16                20.0        17.0
# 2021-05-23                28.0        19.0
# 2021-05-30                 3.0         7.0
# 2021-06-06                11.0         9.0
# 2021-06-13                 8.0         8.0
# 2021-06-20                16.0        15.0

# %%
# %%time
lstm_train_pred = model_lstm.predict(X_train_series)
# Out:
# CPU times: user 49 ms, sys: 4.02 ms, total: 53 ms
# Wall time: 46.3 ms

# %%
comparison_train = train.copy()
comparison_train = comparison_train[window:]
comparison_train['Prediction'] = lstm_train_pred
comparison_train['Prediction'] = round(comparison_train['Prediction'])
comparison_train.columns = ['Date', 'Actual Death Count', 'Prediction']
comparison_train = comparison_train.set_index('Date')
comparison_train.to_csv('prediction_on_training.csv')
comparison_train
# Out:
#             Actual Death Count  Prediction
# Date
# 2016-07-10                 0.0         3.0
# 2016-07-17                 4.0         1.0
# 2016-07-24                 0.0         2.0
# 2016-07-31                 0.0         4.0
# 2016-08-07                 3.0         1.0
# ...                        ...         ...
# 2021-03-28                26.0        14.0
# 2021-04-04                 7.0        11.0
# 2021-04-11                 4.0        13.0
# 2021-04-18                25.0        13.0
# 2021-04-25                 6.0        10.0
#
# [251 rows x 2 columns]

# %% [markdown]
# ### Visualization of Results

# %%
plt.rcParams["figure.figsize"] = [25, 6]

plt.plot(lstm_history.history['loss'], color = 'lightseagreen')
plt.plot(lstm_history.history['val_loss'], color = 'black')
plt.title('Loss vs Epoch', fontsize = 16)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Training Loss', 'Validation Loss'], loc='best', fontsize = 'large')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [25, 6]

comparison_train['Actual Death Count'].plot(linewidth = 2, label = 'Actual', color = 'lightseagreen')
comparison_train.Prediction.plot(linewidth = 1, label = 'Prediction', color = 'black', linestyle = '--')
plt.legend(fontsize = 'large')
plt.ylabel('No of Deaths')
plt.title('Comparison of Actual and Prediction (Train Set): LSTM', fontsize = 16)
plt.show()

# %%
plt.rcParams["figure.figsize"] = [12, 6]

comparison['Actual Death Count'].plot(linewidth = 2, label = 'Actual', color = 'lightseagreen')
comparison.Prediction.plot(linewidth = 1, label = 'Prediction', color = 'black', linestyle = '--')
plt.legend(fontsize = 'large')
plt.ylabel('No of Deaths')
plt.title('Comparison of Actual and Prediction (Test Set): LSTM', fontsize = 16)
plt.show()

# %% [markdown]
# ### Evaluation Metrics: Training Set

# %%
# Define a function to calculate MAE and RMSE
from sklearn.metrics import mean_squared_log_error, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics import r2_score

errors = comparison_train['Actual Death Count'] - comparison_train['Prediction']
mse = np.square(errors).mean()
rmse = np.sqrt(mse)
mae = np.abs(errors).mean()
mape = np.abs(errors/comparison_train['Actual Death Count']).mean() * 100
r2 = r2_score(comparison_train['Actual Death Count'], comparison_train['Prediction'])

# %%
print('Mean Absolute Error: {:.4f}'.format(mae))
print('Mean Squared Error: {:.4f}'.format(mse))
print('Root Mean Square Error: {:.4f}'.format(rmse))
print('Mean Absolute Percentage Error: {:.4f}'.format(mape))
print('R2 Score: {:.4f}'.format(r2))
# Out:
# Mean Absolute Error: 7.4781
# Mean Squared Error: 287.1116
# Root Mean Square Error: 16.9444
# Mean Absolute Percentage Error: inf
# R2 Score: 0.2061

# %% [markdown]
# ### Evaluation Metrics: Validation Set

# %%
# Define a function to calculate MAE and RMSE
from sklearn.metrics import mean_squared_log_error, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics import r2_score

errors = comparison['Actual Death Count'] - comparison['Prediction']
mse = np.square(errors).mean()
rmse = np.sqrt(mse)
mae = np.abs(errors).mean()
mape = np.abs(errors/comparison['Actual Death Count']).mean() * 100
r2 = r2_score(comparison['Actual Death Count'], comparison['Prediction'])

# %%
print('Mean Absolute Error: {:.4f}'.format(mae))
print('Mean Squared Error: {:.4f}'.format(mse))
print('Root Mean Square Error: {:.4f}'.format(rmse))
print('Mean Absolute Percentage Error: {:.4f}'.format(mape))
print('R2 Score: {:.4f}'.format(r2))
# Out:
# Mean Absolute Error: 2.7500
# Mean Squared Error: 14.5000
# Root Mean Square Error: 3.8079
# Mean Absolute Percentage Error: 28.8332
# R2 Score: 0.7197

# %% [markdown]
# ## Reference
#
# * https://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/
